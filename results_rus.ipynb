# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Read data

# %%
arr=pd.read_csv('../music/experiment/ArraytrackResults.txt', delimiter='\t')
arr['perSpec'] = 1
arr['smoothing'] = arr['subArrNum'] > 1
arr['backw'] = arr['backwSmth'] == 1
arr['bandwidth'] = 20
arr['decimation'] = False

cols = arr.columns.tolist()
cols = [cols[2]] + cols[3:6] + [cols[0]] + cols[-6:-3] + [cols[-3]] + cols[-2:] + cols[6:11]
arr = arr[cols]
arr['errorNextAngle'] = abs(arr.nextAngle - arr.realAngle)

# %%
ori=pd.read_csv('experiment/OrionResults.txt', delimiter='\t')
ori['smoothing'] = ori['smoothing'] == 1
ori['backw'] = ori['backw'] == 1
ori['decimation'] = ori['decimation'] == 1
ori = ori.rename(columns={'packetPerSpec':'perSpec'})
ori.drop(columns=['SNR', 'realAngle', 'Kfactor'], inplace=True)
ori = ori.merge(arr[['seed', 'SNR', 'realAngle', 'Kfactor']].drop_duplicates().reset_index(drop=True))
ori['errorAngle'] = abs(ori.estAngle - ori.realAngle)
ori['errorNextAngle'] = abs(ori.nextAngle - ori.realAngle)

cols = ori.columns.tolist()
cols = [cols[1]] + [cols[-4]] + [cols[-2]] + [cols[-3]] + [cols[0]] + cols[7:9] + cols[-6:-4] + cols[-8:-6] + cols[2:7] + [cols[-1]]
ori = ori[cols]

# %%
ori_old=pd.read_csv('../music/experiment/OrionResults.txt', delimiter='\t')
ori_old['smoothing'] = False
ori_old['backw'] = False
ori_old['decimation'] = ori_old['decimation'] == 1
ori_old = ori_old.rename(columns={'packetPerSpec':'perSpec'})
ori_old['errorNextAngle'] = abs(ori_old.nextAngle - ori_old.realAngle)

cols = ori_old.columns.tolist()
cols = cols[1:5] + [cols[0]] + cols[-7:-5] + cols[-3:-1] + cols[-5:-3] + cols[5:10] + [cols[-1]]
ori_old = ori_old[cols]

# %%
spotfi=pd.read_csv('SpotfiClusters/SpotfiResults.txt', delimiter='\t')
spotfi=spotfi.merge(arr[['seed', 'SNR', 'realAngle', 'Kfactor']].drop_duplicates().reset_index(drop=True))
spotfi['errorAngle'] = abs(spotfi.meanA1 - spotfi.realAngle)
spotfi['errorNextAngle'] = abs(spotfi.realAngle - spotfi.meanA2)
spotfi['errorNextNextAngle'] = abs(spotfi.realAngle - spotfi.meanA3)
spotfi = spotfi.rename(columns={'packetPerSpec':'perSpec'})
spotfi.smoothing = spotfi.smoothing == 1
spotfi.backw = spotfi.backw == 1
spotfi.decimation = spotfi.decimation == 1
spotfi['estAngle'] = spotfi.meanA1
spotfi['nextAngle'] = spotfi.meanA2
spotfi['nextNextAngle'] = spotfi.meanA3

cols = spotfi.columns.tolist()
cols = [cols[1]] + [cols[-9], cols[-7], cols[-8]] + [cols[0]] + cols[4:6] + cols[2:4] + cols[6:8] + cols[-3:] + cols[-6:-3] + cols[8:-9]
spotfi = spotfi[cols]

spotfi['spectrumsNum'] = (spotfi.packetNum / spotfi.perSpec)

# %%
spotfi_fixed=pd.read_csv('SpotfiClusters/SpotfiResults_fixed_eigen.txt', delimiter='\t')
spotfi_fixed=spotfi_fixed.merge(arr[['seed', 'SNR', 'realAngle', 'Kfactor']].drop_duplicates().reset_index(drop=True))
spotfi_fixed['errorAngle'] = abs(spotfi_fixed.meanA1 - spotfi_fixed.realAngle)
spotfi_fixed['errorNextAngle'] = abs(spotfi_fixed.realAngle - spotfi_fixed.meanA2)
spotfi_fixed['errorNextNextAngle'] = abs(spotfi_fixed.realAngle - spotfi_fixed.meanA3)
spotfi_fixed = spotfi_fixed.rename(columns={'packetPerSpec':'perSpec'})
spotfi_fixed.smoothing = spotfi_fixed.smoothing == 1
spotfi_fixed.backw = spotfi_fixed.backw == 1
spotfi_fixed.decimation = spotfi_fixed.decimation == 1
spotfi_fixed['estAngle'] = spotfi_fixed.meanA1
spotfi_fixed['nextAngle'] = spotfi_fixed.meanA2
spotfi_fixed['nextNextAngle'] = spotfi_fixed.meanA3

cols = spotfi_fixed.columns.tolist()
cols = [cols[1]] + [cols[-9], cols[-7], cols[-8]] + [cols[0]] + cols[4:6] + cols[2:4] + cols[6:8] + cols[-3:] + cols[-6:-3] + cols[8:-9]
spotfi_fixed = spotfi_fixed[cols]

spotfi_fixed['spectrumsNum'] = (spotfi_fixed.packetNum / spotfi_fixed.perSpec)
spotfi_fixed['minErrorAngle'] = spotfi_fixed[['errorAngle','errorNextAngle','errorNextNextAngle']].min(axis=1)

# %%
spotfi_fixed_1=pd.read_csv('SpotfiClusters/SpotfiResults_fixed_eigen_1.txt', delimiter='\t')
spotfi_fixed_1=spotfi_fixed_1.merge(arr[['seed', 'SNR', 'realAngle', 'Kfactor']].drop_duplicates().reset_index(drop=True))
spotfi_fixed_1['errorAngle'] = abs(spotfi_fixed_1.meanA1 - spotfi_fixed_1.realAngle)
spotfi_fixed_1['errorNextAngle'] = abs(spotfi_fixed_1.realAngle - spotfi_fixed_1.meanA2)
spotfi_fixed_1['errorNextNextAngle'] = abs(spotfi_fixed_1.realAngle - spotfi_fixed_1.meanA3)
spotfi_fixed_1 = spotfi_fixed_1.rename(columns={'packetPerSpec':'perSpec'})
spotfi_fixed_1.smoothing = spotfi_fixed_1.smoothing == 1
spotfi_fixed_1.backw = spotfi_fixed_1.backw == 1
spotfi_fixed_1.decimation = spotfi_fixed_1.decimation == 1
spotfi_fixed_1['estAngle'] = spotfi_fixed_1.meanA1
spotfi_fixed_1['nextAngle'] = spotfi_fixed_1.meanA2
spotfi_fixed_1['nextNextAngle'] = spotfi_fixed_1.meanA3

cols = spotfi_fixed_1.columns.tolist()
cols = [cols[1]] + [cols[-9], cols[-7], cols[-8]] + [cols[0]] + cols[4:6] + cols[2:4] + cols[6:8] + cols[-3:] + cols[-6:-3] + cols[8:-9]
spotfi_fixed_1 = spotfi_fixed_1[cols]

spotfi_fixed_1['spectrumsNum'] = (spotfi_fixed_1.packetNum / spotfi_fixed_1.perSpec)
spotfi_fixed_1['minErrorAngle'] = spotfi_fixed_1[['errorAngle','errorNextAngle','errorNextNextAngle']].min(axis=1)

# %%
spotfi_40=pd.read_csv('SpotfiClusters/SpotfiResults_40.txt', delimiter='\t')
spotfi_40=spotfi_40.merge(arr[['seed', 'SNR', 'realAngle', 'Kfactor']].drop_duplicates().reset_index(drop=True))
spotfi_40['errorAngle'] = abs(spotfi_40.meanA1 - spotfi_40.realAngle)
spotfi_40['errorNextAngle'] = abs(spotfi_40.realAngle - spotfi_40.meanA2)
spotfi_40['errorNextNextAngle'] = abs(spotfi_40.realAngle - spotfi_40.meanA3)
spotfi_40 = spotfi_40.rename(columns={'packetPerSpec':'perSpec'})
spotfi_40.smoothing = spotfi_40.smoothing == 1
spotfi_40.backw = spotfi_40.backw == 1
spotfi_40.decimation = spotfi_40.decimation == 1
spotfi_40['estAngle'] = spotfi_40.meanA1
spotfi_40['nextAngle'] = spotfi_40.meanA2
spotfi_40['nextNextAngle'] = spotfi_40.meanA3

cols = spotfi_40.columns.tolist()
cols = [cols[1]] + [cols[-9], cols[-7], cols[-8]] + [cols[0]] + cols[4:6] + cols[2:4] + cols[6:8] + cols[-3:] + cols[-6:-3] + cols[8:-9]
spotfi_40 = spotfi_40[cols]

spotfi_40['spectrumsNum'] = (spotfi_40.packetNum / spotfi_40.perSpec)
spotfi_40['minErrorAngle'] = spotfi_40[['errorAngle','errorNextAngle','errorNextNextAngle']].min(axis=1)

# %% [markdown]
# # Look at data

# %%
arr.head()
# Out:
#    seed     SNR  Kfactor  realAngle  ant  packetNum  perSpec  smoothing  \
# 0     1  8.3404  16.5439    39.6584    8         30        1       True
# 1     1  8.3404  16.5439    39.6584    8         10        1       True
# 2     1  8.3404  16.5439    39.6584    8         30        1       True
# 3     1  8.3404  16.5439    39.6584    8         10        1       True
# 4     1  8.3404  16.5439    39.6584    8         30        1      False
#
#    backw  bandwidth  decimation  estAngle  stdAngle  errorAngle  nextAngle  \
# 0   True         20       False   39.6833  0.059209    0.024925      999.0
# 1   True         20       False   39.6900  0.073786    0.031591      999.0
# 2  False         20       False   39.6833  0.059209    0.024925      999.0
# 3  False         20       False   39.6900  0.073786    0.031591      999.0
# 4   True         20       False   39.7367  0.049013    0.078258      999.0
#
#    stdNextAngle  errorNextAngle
# 0         999.0        959.3416
# 1         999.0        959.3416
# 2         999.0        959.3416
# 3         999.0        959.3416
# 4         999.0        959.3416

# %%
ori_old.head()
# Out:
#    seed     SNR  Kfactor  realAngle  ant  packetNum  perSpec  smoothing  \
# 0     1  8.3404  16.5439    39.6584    8         10        2      False
# 1     1  8.3404  16.5439    39.6584    8         10        2      False
# 2     1  8.3404  16.5439    39.6584    8         10        1      False
# 3     1  8.3404  16.5439    39.6584    8         10        1      False
# 4     1  8.3404  16.5439    39.6584    8         10        2      False
#
#    backw  bandwidth  decimation  estAngle  stdAngle  errorAngle  nextAngle  \
# 0  False         40       False   39.6733  0.070373    0.014925   -54.1333
# 1  False         40       False   39.7200  0.044721    0.061591   -55.6200
# 2  False         40       False   39.8167  0.101990    0.158260   -15.1333
# 3  False         40       False   39.8100  0.128670    0.151590    -0.9100
# 4  False         40        True   39.8733  0.070373    0.214920   -51.6000
#
#    stdNextAngle  errorNextAngle
# 0        2.8215         93.7917
# 1        1.8116         95.2784
# 2        3.6398         54.7917
# 3        3.3044         40.5684
# 4        2.9367         91.2584

# %%
spotfi.head()
# Out:
#    seed     SNR  Kfactor  realAngle  ant  packetNum  perSpec  smoothing  \
# 0     1  8.3404  16.5439    39.6584    8         30        1      False
# 1     1  8.3404  16.5439    39.6584    8         30        1      False
# 2     1  8.3404  16.5439    39.6584    8         30        2      False
# 3     1  8.3404  16.5439    39.6584    8         30        2      False
# 4     1  8.3404  16.5439    39.6584    8         10        1      False
#
#    backw  bandwidth  ...  stdA4  stdD4  meanA4  meanD4  clSize5  stdA5  stdD5  \
# 0  False         20  ...    NaN    NaN     NaN     NaN        0    NaN    NaN
# 1  False         20  ...    NaN    NaN     NaN     NaN        0    NaN    NaN
# 2  False         20  ...    NaN    NaN     NaN     NaN        0    NaN    NaN
# 3  False         20  ...    NaN    NaN     NaN     NaN        0    NaN    NaN
# 4  False         20  ...    NaN    NaN     NaN     NaN        0    NaN    NaN
#
#    meanA5  meanD5  spectrumsNum
# 0     NaN     NaN          30.0
# 1     NaN     NaN          30.0
# 2     NaN     NaN          15.0
# 3     NaN     NaN          15.0
# 4     NaN     NaN          10.0
#
# [5 rows x 43 columns]

# %%
spotfi_fixed.head()
# Out:
#    seed     SNR  Kfactor  realAngle  ant  packetNum  perSpec  smoothing  \
# 0     1  8.3404  16.5439    39.6584    8         30        1      False
# 1     1  8.3404  16.5439    39.6584    8         30        1      False
# 2     1  8.3404  16.5439    39.6584    8         30        2      False
# 3     1  8.3404  16.5439    39.6584    8         30        2      False
# 4     1  8.3404  16.5439    39.6584    8         10        1      False
#
#    backw  bandwidth  ...  stdD4  meanA4  meanD4  clSize5  stdA5  stdD5  \
# 0  False         20  ...    NaN     NaN     NaN        0    NaN    NaN
# 1  False         20  ...    NaN     NaN     NaN        0    NaN    NaN
# 2  False         20  ...    NaN     NaN     NaN        0    NaN    NaN
# 3  False         20  ...    NaN     NaN     NaN        0    NaN    NaN
# 4  False         20  ...    NaN     NaN     NaN        0    NaN    NaN
#
#    meanA5  meanD5  spectrumsNum  minErrorAngle
# 0     NaN     NaN          30.0         0.3416
# 1     NaN     NaN          30.0         0.3416
# 2     NaN     NaN          15.0         0.3416
# 3     NaN     NaN          15.0         0.3416
# 4     NaN     NaN          10.0         0.3416
#
# [5 rows x 44 columns]

# %%
spotfi_fixed_1.head()
# Out:
#    seed     SNR  Kfactor  realAngle  ant  packetNum  perSpec  smoothing  \
# 0     1  8.3404  16.5439    39.6584    8         30        1      False
# 1     1  8.3404  16.5439    39.6584    8         30        1      False
# 2     1  8.3404  16.5439    39.6584    8         30        2      False
# 3     1  8.3404  16.5439    39.6584    8         30        2      False
# 4     1  8.3404  16.5439    39.6584    8         10        1      False
#
#    backw  bandwidth  ...  stdD4  meanA4  meanD4  clSize5  stdA5  stdD5  \
# 0  False         20  ...    NaN     NaN     NaN        0    NaN    NaN
# 1  False         20  ...    NaN     NaN     NaN        0    NaN    NaN
# 2  False         20  ...    NaN     NaN     NaN        0    NaN    NaN
# 3  False         20  ...    NaN     NaN     NaN        0    NaN    NaN
# 4  False         20  ...    NaN     NaN     NaN        0    NaN    NaN
#
#    meanA5  meanD5  spectrumsNum  minErrorAngle
# 0     NaN     NaN          30.0         0.3416
# 1     NaN     NaN          30.0         0.3416
# 2     NaN     NaN          15.0         0.3416
# 3     NaN     NaN          15.0         0.3416
# 4     NaN     NaN          10.0         0.3416
#
# [5 rows x 44 columns]

# %%
p1 = param(alg="orion", sm=0, backw=0, packNum=10, seed_lim=7500)
p2 = param(alg="orion_old", sm=0, backw=0, packNum=10, seed_lim=7500)

p = [p1,p2]

plotResults(p, [0, 70], "Orion old/new", 20, 0, ant=4)

# %%
p1 = param(alg="spotfi_fixed", ant=4, sm=1, backw=0, packNum=10, seed_lim=3000)
p2 = param(alg="spotfi_fixed_1", ant=4, sm=1, backw=0, packNum=10, seed_lim=3000)

p = [p1,p2]

plotResults(p, [0, 70], "Algorithms comparison, abs angles: [0, 70]", 20, 0)

# %% [markdown]
# # Let's look at CDF of data

# %%
class param:
    def __init__(self, alg, backw, packNum, ant=4, sm=0, perSpec=1, band=20, dec=0, seed_lim=10000, 
                pr=False, xy=(0,0)):
        self.alg = alg
        self.ant = ant
        self.sm = sm
        self.backw = backw
        self.packNum = packNum
        self.perSpec = perSpec
        self.band = band
        self.dec = dec
        self.seed_lim = seed_lim
        self.pr = pr
        self.xy = xy

# %%
def bool2str(x):
    if x:
        return str(1)
    else:
        return str(0)

def plotResults(paramList, angleLimits, title, xlim, level, ant = 0, out=0, loc='lower right', short=0, pack=1):
    fig, axes = plt.subplots(figsize=(14,8))

    for param in paramList:
        if param.alg == "arraytrack":
            df = arr
            label = "Arraytrack"
            if param.backw:
                label += " + backward smoothing"
            if short == 0:
                label += ", packNum=" + str(param.packNum)
            param.sm = 1; param.band=20; param.dec=0; param.perSpec = 1;
        elif param.alg == "music":
            df = arr
            label = "Классический MUSIC"
            if param.backw:
                label = "Алгоритм Пиллая"
            if short == 0:
                label += ", packNum=" + str(param.packNum)
            param.sm = 0; param.band=20; param.dec=0; param.perSpec = 1;
        elif param.alg == "orion":
            df = ori
            label = "Orion"
            if short == 0:
                if param.backw & param.sm:
                    label += " + spatial and backward smoothing"
                elif param.backw:
                    label += " + backward smoothing"
                elif param.sm:
                    label += " + spatial smoothing"

                if param.perSpec > 1:
                    label += " + multiple packets"

                label += ", packNum=" + str(param.packNum) + ", band=" + str(param.band) + \
                    ", dec=" + bool2str(param.dec)
        elif param.alg == "spotfi_fixed":
            df = spotfi_fixed
            label = "Spotfi"
            param.perSpec = 1;
            if param.backw:
                label = "Chen’s algorithm"
            if not param.sm:
                label += ", without spatial smoothing"
            
            if short == 0:
                label += ", packNum=" + str(param.packNum) + ", band=" + str(param.band) + \
                    ", dec=" + bool2str(param.dec)
        elif param.alg == "oparray_fixed":
            df = spotfi_fixed
            label = "OpArray"
            param.perSpec = 2;
            if short == 0:
                if param.backw:
                    label += " + backward smoothing"
                if not param.sm:
                    label += ", without spatial smoothing"

                label += ", packNum=" + str(param.packNum) + ", band=" + str(param.band) + \
                    ", dec=" + bool2str(param.dec)
        elif param.alg == "spotfi_40":
            df = spotfi_40
            label = "Spotfi (40МГц)"
            param.perSpec = 1;
            if param.backw:
                label = "Chen’s algorithm"
            if not param.sm:
                label += ", without spatial smoothing"
            
            if short == 0:
                label += ", packNum=" + str(param.packNum) + ", band=" + str(param.band) + \
                    ", dec=" + bool2str(param.dec)
        elif param.alg == "oparray_40":
            df = spotfi_40
            label = "OpArray (40 МГц)"
            param.perSpec = 2;
            if param.backw:
                label += " + backward smoothing"
            if not param.sm:
                label += ", without spatial smoothing"
            
            label += ", packNum=" + str(param.packNum) + ", band=" + str(param.band) + \
                ", dec=" + bool2str(param.dec)
        elif param.alg == "orion_old":
            df = ori_old
            label = "Orion (old)"
            label += " (ant: " + str(param.ant) + "; sm: " + bool2str(param.sm) + \
                "; backw: " + bool2str(param.backw) + "; packNum: " + str(param.packNum) + \
                "; perSpec: " + str(param.perSpec) + "; band: " + str(param.band) + \
                "; dec: " + bool2str(param.dec) + ")"
        elif param.alg == "spotfi":
            df = spotfi
            label = "Spotfi (eigen threshold)"
            param.perSpec = 1;
            label += " (ant: " + str(param.ant) + "; sm: " + bool2str(param.sm) + \
                "; backw: " + bool2str(param.backw) + "; packNum: " + str(param.packNum) + \
                "; band: " + str(param.band) + \
                "; dec: " + bool2str(param.dec) + ")"
        elif param.alg == "oparray_fixed_min":
            df = spotfi_fixed
            label = "OpArray (fixed eigen + min error)"
            param.perSpec = 2;
            label += " (ant: " + str(param.ant) + "; sm: " + bool2str(param.sm) + \
                "; backw: " + bool2str(param.backw) + "; packNum: " + str(param.packNum) + \
                "; band: " + str(param.band) + \
                "; dec: " + bool2str(param.dec) + ")"
        elif param.alg == "spotfi_fixed_1":
            df = spotfi_fixed_1
            label = "Spotfi (fixed eigen 1)"
            param.perSpec = 1;
            label += " (ant: " + str(param.ant) + "; sm: " + bool2str(param.sm) + \
                "; backw: " + bool2str(param.backw) + "; packNum: " + str(param.packNum) + \
                "; band: " + str(param.band) + \
                "; dec: " + bool2str(param.dec) + ")"
        elif param.alg == "spotfi_fixed_min":
            df = spotfi_fixed
            label = "Spotfi (fixed eigen + min error)"
            param.perSpec = 1;
            label += " (ant: " + str(param.ant) + "; sm: " + bool2str(param.sm) + \
                "; backw: " + bool2str(param.backw) + "; packNum: " + str(param.packNum) + \
                "; band: " + str(param.band) + \
                "; dec: " + bool2str(param.dec) + ")"
        elif param.alg == "oparray":
            df = spotfi
            label = "OpArray (eigen threshold)"
            param.perSpec = 2;
            label += " (ant: " + str(param.ant) + "; sm: " + bool2str(param.sm) + \
                "; backw: " + bool2str(param.backw) + "; packNum: " + str(param.packNum) + \
                "; band: " + str(param.band) + \
                "; dec: " + bool2str(param.dec) + ")" 
            
        if short == 1:
            if param.dec == 1:
                label += " с децимацией"
                
        if pack == 1:
                label += ", " + str(param.packNum) + " пакетов"
                
        if ant == 0:
            a = param.ant
            if param.ant == 4:
                label += ", 4 антенны"
            if param.ant == 8:
                label += ", 8 антенн"
        else:
            a = ant
        
        df = df[(abs(df.realAngle) < angleLimits[1]) & (abs(df.realAngle) > angleLimits[0]) \
                & (df.ant == a) & (df.smoothing == param.sm) \
                & (df.backw == param.backw) & (df.packetNum == param.packNum) \
                & (df.perSpec == param.perSpec) & (df.bandwidth == param.band) \
                & (df.decimation == param.dec) & (df.seed < param.seed_lim)].drop_duplicates('seed')

        if param.alg == "spotfi_fixed_min":
            sorted_df = np.sort(df.minErrorAngle)
        elif param.alg == "oparray_fixed_min":
            sorted_df = np.sort(df.minErrorAngle)
        else:
            sorted_df = np.sort(df.errorAngle)
            
        p = 1. * np.arange(len(sorted_df)) / (len(sorted_df) - 1)

        sub_p = abs(p-level)
        ind=np.where(sub_p == np.amin(sub_p))
        val = round(sorted_df[ind[0][0]]*100)/100
        if out:
            print(val)
        if param.pr == True:
            plt.annotate(str(val), xy=(val, level), xytext=param.xy,
                 arrowprops=dict(facecolor='black', shrink=0.01, width=1), size=15)
        
        plt.plot(sorted_df, p, label=label)

    if level > 0:
        plt.plot([level for i in range(100)], 'silver')
    
    if ant == 4:
        title += ", 4 антенны"
    if ant == 8:
        title += ", 8 антенн"
        
    plt.legend(loc=loc, fontsize=14)
    if short == 0:
                axes.set_title(title, fontdict={'fontsize':30})
    axes.set_xlabel('Ошибка в определении угла в градусах', size=25)
    axes.set_ylabel('p', size=25)
    axes.yaxis.set_tick_params(labelsize=15)
    axes.xaxis.set_tick_params(labelsize=15)
    axes.set_xlim([0, xlim])

# %% [markdown]
# # Arraytrack or Music?

# %%
p1 = param(alg="arraytrack", backw=0, packNum=10, seed_lim=10000, pr=True, xy=(5.5,0.6))
p2 = param(alg="music", backw=0, packNum=10, seed_lim=10000, pr=True, xy=(4,0.5))

p = [p1,p2]

plotResults(p, [0, 70], "Arraytrack и классический Music", 10, 0.8, ant=4)

# %%
p1 = param(alg="arraytrack", backw=0, packNum=10, seed_lim=10000, pr=True, xy=(3,0.7))
p2 = param(alg="music", backw=0, packNum=10, seed_lim=10000, pr=True, xy=(0.3,0.94))

p = [p1,p2]

plotResults(p, [0, 70], "Arraytrack и классический Music", 10, 0.8, ant=8)

# %% [markdown]
# 1) Classical music is better than Arraytrack. It is more noticeable in the case of 4 antennas.
#
# 2) Number of packets doesn't affect estimation accuracy in case of Arraytrack and Music.

# %% [markdown]
# # Packet number influence for Arraytrack and Music?

# %%
p1 = param(alg="arraytrack", ant=4, backw=0, packNum=10, seed_lim=10000, pr=True, xy=(5.5,0.6))
p2 = param(alg="arraytrack", ant=4, backw=0, packNum=30, seed_lim=10000)
p3 = param(alg="arraytrack", ant=8, backw=0, packNum=10, seed_lim=10000, pr=True, xy=(3.5,0.4))
p4 = param(alg="arraytrack", ant=8, backw=0, packNum=30, seed_lim=10000)

p = [p1,p2, p3,p4]

plotResults(p, [0, 70], "Влияние числа пакетов на Arraytrack", 10, 0.8)

# %%
p1 = param(alg="arraytrack", ant=4, backw=0, packNum=10, seed_lim=10000)
p2 = param(alg="arraytrack", ant=4, backw=0, packNum=30, seed_lim=10000)
p3 = param(alg="arraytrack", ant=8, backw=0, packNum=10, seed_lim=10000)
p4 = param(alg="arraytrack", ant=8, backw=0, packNum=30, seed_lim=10000)
p5 = param(alg="music", ant=4, backw=0, packNum=10, seed_lim=10000)
p6 = param(alg="music", ant=4, backw=0, packNum=30, seed_lim=10000)
p7 = param(alg="music", ant=8, backw=0, packNum=10, seed_lim=10000)
p8 = param(alg="music", ant=8, backw=0, packNum=30, seed_lim=10000)

p = [p1,p2,p3,p4,p5,p6,p7,p8]

plotResults(p, [0, 70], "Влияние числа пакетов на Arraytrack и Classical Music", 10, 0, short=1)

# %%
p1 = param(alg="music", backw=0, packNum=10, seed_lim=10000)
p2 = param(alg="music", backw=0, packNum=30, seed_lim=10000)
p3 = param(alg="arraytrack", backw=0, packNum=10, seed_lim=10000)
p4 = param(alg="arraytrack", backw=0, packNum=30, seed_lim=10000)

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Влияние числа пакетов на Arraytrack и Classical Music", 10, 0, ant=8)

# %%
p1 = param(alg="music", ant=4, backw=0, packNum=10, seed_lim=10000, pr=True, xy=(5,0.5))
p2 = param(alg="music", ant=4, backw=0, packNum=30, seed_lim=10000)
p3 = param(alg="music", ant=8, backw=0, packNum=10, seed_lim=10000, pr=True, xy=(2.5,0.4))
p4 = param(alg="music", ant=8, backw=0, packNum=30, seed_lim=10000)

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Влияние числа пакетов на классический Music", 10, 0.8)

# %% [markdown]
# 1) Classical music is better than Arraytrack. It is more noticeable in the case of 4 antennas.
#
# 2) Number of packets doesn't affect estimation accuracy in case of Arraytrack and Music.

# %% [markdown]
# # What about backward smoothing for Arraytrack and Music?

# %%
p1 = param(alg="arraytrack", backw=0, packNum=10, seed_lim=10000, pr=True, xy=(5,0.6))
p2 = param(alg="arraytrack", backw=1, packNum=10, seed_lim=10000, pr=True, xy=(4,0.5))
p3 = param(alg="music", backw=0, packNum=10, seed_lim=10000, pr=True, xy=(3,0.4))
p4 = param(alg="music", backw=1, packNum=10, seed_lim=10000, pr=True, xy=(1,0.9))

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Обратное сглаживание для Arraytrack and Music", 10, 0.8, ant=4)

# %% [markdown]
# 1) Backward smoothing increases accuracy in case of 4 antennas.

# %%
p1 = param(alg="arraytrack", backw=0, packNum=10, seed_lim=10000, pr=True, xy=(2,0.6))
p2 = param(alg="arraytrack", backw=1, packNum=10, seed_lim=10000)
p3 = param(alg="music", backw=0, packNum=10, seed_lim=10000, pr=True, xy=(0.3,0.9))
p4 = param(alg="music", backw=1, packNum=10, seed_lim=10000)

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Обратное сглаживание для Arraytrack и Music", 5, 0.8, ant=8, out=1)
# Out:
# 1.29
# 1.26
# 1.11
# 1.19

# %% [markdown]
# 1) However backward smoothing decreases accuracy in case of 8 antennas.

# %% [markdown]
# # Which configuration of Orion is the best?

# %%
p1 = param(alg="orion", ant=4, backw=0, packNum=10, seed_lim=10000)
p2 = param(alg="orion", ant=4, backw=0, packNum=30, seed_lim=10000)
p3 = param(alg="orion", ant=8, backw=0, packNum=10, seed_lim=10000)
p4 = param(alg="orion", ant=8, backw=0, packNum=30, seed_lim=10000)

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Влияние числа пакетов на Orion", 10, 0.8)

# %%
p1 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=20, dec=0, seed_lim=10000, pr=True, xy=(5,0.5))
p2 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=2, band=20, dec=0, seed_lim=10000, pr=True, xy=(6.5,0.6))
p3 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=40, dec=0, seed_lim=10000, pr=True, xy=(2,0.9))
p4 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=2, band=40, dec=0, seed_lim=10000, pr=True, xy=(2.5,0.5))

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Влияние числа пакетов на Orion", 10, 0.8, ant=4, out=1)
# Out:
# 4.47
# 5.0
# 3.28
# 3.53

# %%
p1 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=20, dec=0, seed_lim=10000)
p2 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=2, band=20, dec=0, seed_lim=10000)
p3 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=40, dec=0, seed_lim=10000)
p4 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=2, band=40, dec=0, seed_lim=10000)

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Влияние кратных пакетов на Orion", 10, 0.8, ant=8, out=1)
# Out:
# 1.51
# 1.78
# 1.47
# 1.71

# %%
p1 = param(alg="orion", perSpec=1, sm=0, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(8,0.65))
p2 = param(alg="orion", perSpec=1, sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p3 = param(alg="orion", perSpec=1, sm=0, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p4 = param(alg="orion", perSpec=1, sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(2,0.95))

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Влияние сглаживания на Orion", 20, 0.8, ant=4, out=1)
# Out:
# 4.47
# 4.76
# 4.53
# 4.53

# %%
p1 = param(alg="orion", perSpec=1, sm=0, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(1,0.95))
p2 = param(alg="orion", perSpec=1, sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p3 = param(alg="orion", perSpec=1, sm=0, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p4 = param(alg="orion", perSpec=1, sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(7,0.65))

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Влияние сглаживания на Orion", 20, 0.8, ant=8, out=1)
# Out:
# 1.51
# 1.69
# 1.95
# 2.01

# %% [markdown]
# 1) Multiple packets per spectrum decrease accuracy
#
# 2) Wider bandwidth increases accuracy

# %% [markdown]
# # What about subcarrier decimation in case of Orion?

# %%
p1 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=20, dec=0, seed_lim=10000, pr=True, xy=(2.5,0.95))
p2 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=20, dec=1, seed_lim=10000, pr=True, xy=(6,0.5))
p3 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=40, dec=0, seed_lim=10000, pr=True, xy=(1.5,0.9))
p4 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=40, dec=1, seed_lim=10000, pr=True, xy=(4,0.95))

p = [p1,p2]

plotResults(p, [0, 70], "Влияние прореживания поднесущих на Orion", 10, 0.8, ant=4)

# %%
p1 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=20, dec=0, seed_lim=2000)
p2 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=20, dec=1, seed_lim=2000)

p = [p1,p2]

plotResults(p, [0, 70], "Влияние прореживания поднесущих на Orion", 10, 0, ant=8, short=1)

# %% [markdown]
# 1) More subcarriers - better accuracy.

# %% [markdown]
# # Which configuration of Spotfi is better?

# %%
p1 = param(alg="spotfi_fixed", sm=0, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(12,0.65))
p2 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p3 = param(alg="spotfi_fixed", sm=0, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p4 = param(alg="spotfi_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(2,0.95))

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Smoothing influence on Spotfi", 20, 0.8, ant=4, out=1)
# Out:
# 8.93
# 7.53
# 7.93
# 7.46

# %%
p1 = param(alg="spotfi_fixed", sm=0, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(13,0.6))
p2 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(6,0.4))
p3 = param(alg="spotfi_fixed", sm=0, backw=1, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(10,0.5))
p4 = param(alg="spotfi_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(1.5,0.9))

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Smoothing influence on Spotfi", 20, 0.8, ant=8, out=1)
# Out:
# 8.76
# 4.48
# 6.49
# 3.82

# %% [markdown]
# 1) Smoothing INCREASES accuracy when eigen values amount is FIXED.
#
# 2) Backward smoothing INCREASES accuracy when eigen values amount is FIXED.

# %%
p1 = param(alg="spotfi_fixed", ant=4, sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(10,0.6))
p2 = param(alg="spotfi_fixed", ant=4, sm=1, backw=0, packNum=30, band=20, dec=0, seed_lim=10000, pr=True, xy=(4,0.9))
p3 = param(alg="spotfi_fixed", ant=8, sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(6.5,0.5))
p4 = param(alg="spotfi_fixed", ant=8, sm=1, backw=0, packNum=30, band=20, dec=0, seed_lim=10000, pr=True, xy=(2,0.95))

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Влияние числа пакетов на Spotfi", 15, 0.8, short=1, pack=1)

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(9,0.6))
p2 = param(alg="spotfi_fixed", sm=1, backw=1, packNum=30, band=20, dec=0, seed_lim=10000, pr=True, xy=(5,0.9))

p = [p1,p2]

plotResults(p, [0, 70], "Packet number influence on Spotfi", 10, 0.8, ant=4)

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(7,0.6))
p2 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=30, band=20, dec=0, seed_lim=10000, pr=True, xy=(2,0.95))

p = [p1,p2]

plotResults(p, [0, 70], "Packet number influence on Spotfi", 20, 0.8, ant=8, short=1, pack=1)

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p2 = param(alg="spotfi_fixed", sm=1, backw=1, packNum=30, band=20, dec=0, seed_lim=10000)

p = [p1,p2]

plotResults(p, [0, 70], "Packet number influence on Spotfi", 20, 0, ant=8)

# %% [markdown]
# 1) Number of packets almost doesn't affect estimation accuracy in case of 4 antennas.
#
# 2) Increase of packet number slightly increases estimation accuracy in case of 8 antennas.

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(11,0.5))
p2 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=1, seed_lim=10000, pr=True, xy=(4,0.95))
p3 = param(alg="spotfi_fixed", ant=8, sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(6,0.55))
p4 = param(alg="spotfi_fixed", ant=8, sm=1, backw=0, packNum=10, band=20, dec=1, seed_lim=10000, pr=True, xy=(2,0.95))

p = [p1,p2, p3, p4]

plotResults(p, [0, 70], "Влияние прореживания поднесущих на Spotfi", 15, 0.8, short=1)

# %% [markdown]
# 1) Decimation almost doesn't affect estimation accuracy in case of 4 antennas.
#
# 2) Decimation slightly decreases estimation accuracy in case of 8 antennas.

# %% [markdown]
# # What about 40MHz for Spotfi and OpArray?

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p2 = param(alg="spotfi_40", sm=1, backw=0, packNum=10, band=40, dec=0, seed_lim=10000)

p = [p1,p2]

plotResults(p, [0, 70], "Bandwidth influence on Spotfi", 20, 0, ant=4)

# %%
p1 = param(alg="spotfi_fixed", ant=4, sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p2 = param(alg="spotfi_40", ant=4, sm=1, backw=0, packNum=10, band=40, dec=0, seed_lim=10000)

p = [p1,p2]

plotResults(p, [0, 70], "Bandwidth influence on Spotfi", 20, 0, ant=4, short=1)

# %%
p1 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p2 = param(alg="oparray_40", sm=1, backw=0, packNum=10, band=40, dec=0, seed_lim=10000)

p = [p1,p2]

plotResults(p, [0, 70], "Bandwidth influence on OpArray", 20, 0, ant=4)

# %%
p1 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p2 = param(alg="oparray_40", sm=1, backw=0, packNum=10, band=40, dec=0, seed_lim=10000)

p = [p1,p2]

plotResults(p, [0, 70], "Bandwidth influence on OpArray", 20, 0, ant=8)

# %% [markdown]
# # Which configuration of OpArray is better?

# %%
p1 = param(alg="oparray_fixed", sm=0, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(13,0.6))
p2 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p3 = param(alg="oparray_fixed", sm=0, backw=1, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(7,0.5))
p4 = param(alg="oparray_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(4,0.95))

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Smoothing influence on OpArray", 20, 0.8, ant=4, out=1)
# Out:
# 9.55
# 7.97
# 8.45
# 7.71

# %%
p1 = param(alg="oparray_fixed", sm=0, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(13,0.6))
p2 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p3 = param(alg="oparray_fixed", sm=0, backw=1, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(8,0.5))
p4 = param(alg="oparray_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(2,0.95))

p = [p1,p2,p3,p4]

plotResults(p, [0, 70], "Smoothing influence on OpArray", 20, 0.8, ant=8, out=1)
# Out:
# 10.99
# 4.36
# 6.27
# 3.99

# %% [markdown]
# 1) Smoothing INCREASES accuracy when eigen values amount is FIXED.
#
# 2) Backward smoothing significantly INCREASES accuracy when eigen values amount is FIXED.

# %%
p1 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(13,0.5))
p2 = param(alg="oparray_fixed", sm=1, backw=0, packNum=30, band=20, dec=0, seed_lim=10000, pr=True, xy=(4,0.95))

p = [p1,p2]

plotResults(p, [0, 70], "Packet number influence on OpArray", 20, 0.8, ant=4)

# %%
p1 = param(alg="oparray_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p2 = param(alg="oparray_fixed", sm=1, backw=1, packNum=30, band=20, dec=0, seed_lim=10000)

p = [p1,p2]

plotResults(p, [0, 70], "Packet number influence on OpArray", 20, 0, ant=4)

# %%
p1 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(6,0.5))
p2 = param(alg="oparray_fixed", sm=1, backw=0, packNum=30, band=20, dec=0, seed_lim=10000, pr=True, xy=(2,0.95))

p = [p1,p2]

plotResults(p, [0, 70], "Packet number influence on OpArray", 10, 0.8, ant=8)

# %%
p1 = param(alg="oparray_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p2 = param(alg="oparray_fixed", sm=1, backw=1, packNum=30, band=20, dec=0, seed_lim=10000)

p = [p1,p2]

plotResults(p, [0, 70], "Packet number influence on OpArray", 10, 0, ant=8)

# %% [markdown]
# 1) Increase of packet number increases estimation accuracy of Orion in all cases.

# %%
p1 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(13,0.5))
p2 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=1, seed_lim=10000, pr=True, xy=(4,0.95))

p = [p1,p2]

plotResults(p, [0, 70], "Decimation influence on OpArray", 20, 0.8, ant=4)

# %%
p1 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(7,0.5))
p2 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=1, seed_lim=10000, pr=True, xy=(2,0.95))

p = [p1,p2]

plotResults(p, [0, 70], "Decimation influence on OpArray", 10, 0.8, ant=8)

# %% [markdown]
# 1) Decimation almost doesn't affect estimation accuracy in case of 4 antennas.
#
# 2) Decimation even slightly increases estimation accuracy in case of 8 antennas.

# %% [markdown]
# # Spotfi or OpArray?

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(4,0.95))
p2 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(13,0.5))

p = [p1,p2]

plotResults(p, [0, 70], "Spotfi vs OpArray", 20, 0.8, ant=4)

# %%
p1 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(13,0.5))
p2 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(4,0.95))

p = [p1,p2]

plotResults(p, [0, 70], "Spotfi or OpArray", 20, 0.8, ant=4)

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p2 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)

p = [p1,p2]

plotResults(p, [0, 70], "Spotfi or OpArray", 20, 0, ant=8)

# %%
p1 = param(alg="oparray_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p2 = param(alg="spotfi_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)

p = [p1,p2]

plotResults(p, [0, 70], "Spotfi or OpArray", 20, 0, ant=8)

# %% [markdown]
# 1) In general Spotfi works better than OpArray.

# %% [markdown]
# # Best algorithms comparison in different angle range

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(10,0.6))
p2 = param(alg="spotfi_fixed", sm=0, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p3 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(11,0.7))
p4 = param(alg="oparray_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p5 = param(alg="arraytrack", backw=0, packNum=10, seed_lim=10000, pr=True, xy=(5,0.55))
p6 = param(alg="music", backw=0, packNum=10, seed_lim=10000, pr=True, xy=(2.5,0.95))
p8 = param(alg="music", backw=1, packNum=10, seed_lim=10000, pr=True, xy=(0.5,0.95))
p9 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=20, dec=0, seed_lim=10000, pr=True, xy=(6,0.6))

p = [p1,p3,p5,p6,p8,p9]

plotResults(p, [0, 70], "Сравнение алгоритмов", 20, 0.8, ant=4, short=1)

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000, pr=True, xy=(8,0.6))
p2 = param(alg="spotfi_fixed", sm=0, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p3 = param(alg="oparray_fixed", sm=1, backw=0, packNum=10, band=20, dec=0, seed_lim=10000)
p4 = param(alg="oparray_fixed", sm=1, backw=1, packNum=10, band=20, dec=0, seed_lim=10000)
p5 = param(alg="arraytrack", backw=0, packNum=10, seed_lim=10000)
p6 = param(alg="music", backw=0, packNum=10, seed_lim=10000)
p8 = param(alg="music", backw=1, packNum=10, seed_lim=10000, pr=True, xy=(0.2,0.95))
p9 = param(alg="orion", sm=0, backw=0, packNum=10, perSpec=1, band=20, dec=0, seed_lim=10000, pr=True, xy=(4,0.6))

p = [p1,p3,p5,p6,p8,p9]

plotResults(p, [0, 70], "Сравнение алгоритмов", 20, 0.8, ant=8, short=1)

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=1, packNum=30, band=20, dec=0, seed_lim=10000, pr=True, xy=(9,0.5))
p2 = param(alg="oparray_fixed", sm=1, backw=1, packNum=30, band=20, dec=0, seed_lim=10000)
p3 = param(alg="arraytrack", backw=1, packNum=30, seed_lim=10000, pr=True, xy=(2.5,0.4))
p4 = param(alg="music", backw=1, packNum=30, seed_lim=10000, pr=True, xy=(1,0.95))
p5 = param(alg="orion_old", sm=0, backw=0, packNum=10, perSpec=1, band=20, dec=0, seed_lim=10000, pr=True, xy=(6,0.6))

p = [p1,p2,p3,p4,p5]

plotResults(p, [0, 70], "Algorithms comparison", 20, 0.8, ant=4)

# %%
p1 = param(alg="spotfi_fixed", sm=1, backw=1, packNum=30, band=20, dec=0, seed_lim=10000)
p2 = param(alg="oparray_fixed", sm=1, backw=1, packNum=30, band=20, dec=1, seed_lim=10000)
p3 = param(alg="arraytrack", backw=0, packNum=30, seed_lim=10000)
p4 = param(alg="music", backw=0, packNum=30, seed_lim=10000)
p5 = param(alg="orion_old", sm=0, backw=0, packNum=10, perSpec=1, band=20, dec=0, seed_lim=10000)

p = [p1,p2,p3,p4,p5]

plotResults(p, [0, 70], "Algorithms comparison", 10, 0.8, ant=8)
